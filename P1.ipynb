# %%
import pandas as pd

#read data to data frame df
df = pd.read_csv("./pitching.csv")

df_yearID=df.groupby("yearID")
df_yearID.get_group(2015)
# Out:
#         playerID nameFirst    nameLast         nameGiven  yearID  stint  \
# 341    aardsda01     David     Aardsma       David Allan    2015      1
# 342     abadfe01  Fernando        Abad  Fernando Antonio    2015      1
# 343    achteaj01     A. J.      Achter       Adam Joseph    2015      1
# 344    adamsau01    Austin       Adams      Austin David    2015      1
# 345    adcocna01    Nathan      Adcock     Nathan Masler    2015      1
# ...          ...       ...         ...               ...     ...    ...
# 44037  youngch03     Chris       Young  Christopher Ryan    2015      1
# 44135  zieglbr01      Brad     Ziegler      Brad Gregory    2015      1
# 44136  zimmejo02    Jordan  Zimmermann         Jordan M.    2015      1
# 44137   zitoba01     Barry        Zito     Barry William    2015      1
# 44138   zychto01      Tony        Zych     Anthony Aaron    2015      1
#
#       teamID lgID   W   L  ...  IBB   WP  HBP  BK    BFP    GF   R   SH   SF  \
# ...

# %%
import pandas as pd

#read data to data frame df
df = pd.read_csv("./pitching.csv")

df_yearID=df.groupby('yearID')
df_yearID.get_group(2015)
# Out:
#         playerID nameFirst    nameLast         nameGiven  yearID  stint  \
# 341    aardsda01     David     Aardsma       David Allan    2015      1
# 342     abadfe01  Fernando        Abad  Fernando Antonio    2015      1
# 343    achteaj01     A. J.      Achter       Adam Joseph    2015      1
# 344    adamsau01    Austin       Adams      Austin David    2015      1
# 345    adcocna01    Nathan      Adcock     Nathan Masler    2015      1
# ...          ...       ...         ...               ...     ...    ...
# 44037  youngch03     Chris       Young  Christopher Ryan    2015      1
# 44135  zieglbr01      Brad     Ziegler      Brad Gregory    2015      1
# 44136  zimmejo02    Jordan  Zimmermann         Jordan M.    2015      1
# 44137   zitoba01     Barry        Zito     Barry William    2015      1
# 44138   zychto01      Tony        Zych     Anthony Aaron    2015      1
#
#       teamID lgID   W   L  ...  IBB   WP  HBP  BK    BFP    GF   R   SH   SF  \
# ...
